# %% [markdown]
# # Plot Analyses And Results
#
# This notebook demonstrates retrieval and plotting through the high-level results service.
#
# It uses `pyecharts` through `ResultsService.plot_results(...)` and can run entirely with in-memory example data.

# %%
from __future__ import annotations

import enum
import sys
from datetime import datetime, timezone
from pathlib import Path

import pandas as pd
from IPython.display import display
from pyecharts.globals import CurrentConfig, NotebookType

if not hasattr(enum, "StrEnum"):
    class _CompatStrEnum(str, enum.Enum):
        pass
    enum.StrEnum = _CompatStrEnum

CurrentConfig.NOTEBOOK_TYPE = NotebookType.JUPYTER_NOTEBOOK

workspace_root = Path.cwd().resolve().parent
sys.path.insert(0, str(workspace_root / "src"))
sys.path.insert(0, str(workspace_root.parent / "owi-metadatabase-sdk" / "src"))

from owi.metadatabase.results import ResultsService, WindSpeedHistogram
from owi.metadatabase.results.analyses.lifetime_design_frequencies import LifetimeDesignFrequencies
from owi.metadatabase.results.analyses.lifetime_design_verification import LifetimeDesignVerification


class StubRepository:
    def __init__(self, frame: pd.DataFrame) -> None:
        self.frame = frame

    def list_results(self, query):
        return self.frame

    def create_analysis(self, payload):
        return payload

    def create_results_bulk(self, payloads):
        return {"items": list(payloads)}

# %% [markdown]
# ## Histogram Example

# %%
histogram_analysis = WindSpeedHistogram()
histogram_series = histogram_analysis.to_results(
    {
        "series": [
            {
                "title": "Design",
                "scope_label": "Site",
                "site_id": 1,
                "bins": [(0.0, 1.0), (1.0, 2.0), (2.0, 3.0)],
                "values": [4.0, 7.0, 3.0],
            },
            {
                "title": "Measured",
                "scope_label": "Site",
                "site_id": 1,
                "bins": [(0.0, 1.0), (1.0, 2.0), (2.0, 3.0)],
                "values": [3.0, 8.0, 4.0],
            },
        ]
    }
)
histogram_frame = pd.DataFrame([item.to_record_payload(analysis_id=101) for item in histogram_series])
histogram_service = ResultsService(repository=StubRepository(histogram_frame))
histogram_data = histogram_service.get_results("WindSpeedHistogram")
histogram_plot = histogram_service.plot_results("WindSpeedHistogram")

display(histogram_data)
display(histogram_plot.chart.render_notebook())
# Out:
#   series_name scope  bin_left  bin_right  value
# 0      Design  Site       0.0        1.0    4.0
# 1      Design  Site       1.0        2.0    7.0
# 2      Design  Site       2.0        3.0    3.0
# 3    Measured  Site       0.0        1.0    3.0
# 4    Measured  Site       1.0        2.0    8.0
# 5    Measured  Site       2.0        3.0    4.0
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v6/echarts.min'
#         }
#     });
# </script>
#
#         <div id="d9d862a642ac43af92f69d32095fcf50" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_d9d862a642ac43af92f69d32095fcf50 = echarts.init(
#                     document.getElementById('d9d862a642ac43af92f69d32095fcf50'), 'white', {renderer: 'canvas', locale: 'ZH'});
#                 var option_d9d862a642ac43af92f69d32095fcf50 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "Design",
#             "legendHoverLink": true,
#             "data": [
#                 4.0,
#                 7.0,
#                 3.0
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "richInheritPlainLabel": true,
#                 "valueAnimation": false
#             }
#         },
#         {
#             "type": "bar",
#             "name": "Measured",
#             "legendHoverLink": true,
#             "data": [
#                 3.0,
#                 8.0,
#                 4.0
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "richInheritPlainLabel": true,
#                 "valueAnimation": false
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Design",
#                 "Measured"
#             ],
#             "selected": {},
#             "show": true,
#             "top": "5%",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10,
#             "triggerEvent": false
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "displayTransition": true,
#         "textStyle": {
#             "fontSize": 14,
#             "richInheritPlainLabel": true
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "name": "Bin",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "nameTruncate": {},
#             "nameMoveOverlap": true,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "silent": false,
#             "triggerEvent": false,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": false
#                 }
#             },
#             "animation": true,
#             "animationThreshold": 2000,
#             "animationDuration": 1000,
#             "animationEasing": "cubicOut",
#             "animationDelay": 0,
#             "animationDurationUpdate": 300,
#             "animationEasingUpdate": "cubicOut",
#             "animationDelayUpdate": 0,
#             "data": [
#                 "[0.0,1.0)",
#                 "[1.0,2.0)",
#                 "[2.0,3.0)"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "Value",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "nameTruncate": {},
#             "nameMoveOverlap": true,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "silent": false,
#             "triggerEvent": false,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": false
#                 }
#             },
#             "animation": true,
#             "animationThreshold": 2000,
#             "animationDuration": 1000,
#             "animationEasing": "cubicOut",
#             "animationDelay": 0,
#             "animationDurationUpdate": 300,
#             "animationEasingUpdate": "cubicOut",
#             "animationDelayUpdate": 0
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "WindSpeedHistogram",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_d9d862a642ac43af92f69d32095fcf50.setOption(option_d9d862a642ac43af92f69d32095fcf50);
#         });
#     </script>

# %% [markdown]
# ## Time-Series Example

# %%
verification_analysis = LifetimeDesignVerification()
verification_series = verification_analysis.to_results(
    {
        "rows": [
            {
                "timestamp": datetime(2024, 1, 1, tzinfo=timezone.utc),
                "turbine": "BBA01",
                "FA1": 0.356,
                "SS1": 0.357,
                "location_id": 5,
            },
            {
                "timestamp": datetime(2024, 1, 2, tzinfo=timezone.utc),
                "turbine": "BBA01",
                "FA1": 0.355,
                "SS1": 0.356,
                "location_id": 5,
            },
        ]
    }
)
verification_frame = pd.DataFrame([item.to_record_payload(analysis_id=102) for item in verification_series])
verification_service = ResultsService(repository=StubRepository(verification_frame))
verification_data = verification_service.get_results("LifetimeDesignVerification")
verification_plot = verification_service.plot_results("LifetimeDesignVerification")

display(verification_data)
verification_plot.chart.render_notebook()
# Out:
#                            x      y  series_name turbine metric
# 0  2024-01-01T00:00:00+00:00  0.356  BBA01 - FA1   BBA01    FA1
# 1  2024-01-02T00:00:00+00:00  0.355  BBA01 - FA1   BBA01    FA1
# 2  2024-01-01T00:00:00+00:00  0.357  BBA01 - SS1   BBA01    SS1
# 3  2024-01-02T00:00:00+00:00  0.356  BBA01 - SS1   BBA01    SS1
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v6/echarts.min'
#         }
#     });
# </script>
#
#         <div id="772353dc4a364e9ba7f98a6972d1e931" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_772353dc4a364e9ba7f98a6972d1e931 = echarts.init(
#                     document.getElementById('772353dc4a364e9ba7f98a6972d1e931'), 'white', {renderer: 'canvas', locale: 'ZH'});
#                 var option_772353dc4a364e9ba7f98a6972d1e931 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "BBA01 - FA1",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "stackStrategy": "samesign",
#             "data": [
#                 {
#                     "value": 0.356,
#                     "symbol": "circle",
#                     "symbolSize": 4,
#                     "symbolKeepAspect": false
#                 },
#                 {
#                     "value": 0.355,
#                     "symbol": "circle",
#                     "symbolSize": 4,
#                     "symbolKeepAspect": false
#                 }
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "richInheritPlainLabel": true,
#                 "valueAnimation": false
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": false
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "BBA01 - SS1",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "stackStrategy": "samesign",
#             "data": [
#                 {
#                     "value": 0.357,
#                     "symbol": "circle",
#                     "symbolSize": 4,
#                     "symbolKeepAspect": false
#                 },
#                 {
#                     "value": 0.356,
#                     "symbol": "circle",
#                     "symbolSize": 4,
#                     "symbolKeepAspect": false
#                 }
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "richInheritPlainLabel": true,
#                 "valueAnimation": false
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": false
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "BBA01 - FA1",
#                 "BBA01 - SS1"
#             ],
#             "selected": {},
#             "show": true,
#             "top": "5%",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10,
#             "triggerEvent": false
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "displayTransition": true,
#         "textStyle": {
#             "fontSize": 14,
#             "richInheritPlainLabel": true
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "name": "Time / Axis",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "nameTruncate": {},
#             "nameMoveOverlap": true,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "silent": false,
#             "triggerEvent": false,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": false
#                 }
#             },
#             "animation": true,
#             "animationThreshold": 2000,
#             "animationDuration": 1000,
#             "animationEasing": "cubicOut",
#             "animationDelay": 0,
#             "animationDurationUpdate": 300,
#             "animationEasingUpdate": "cubicOut",
#             "animationDelayUpdate": 0,
#             "data": [
#                 "2024-01-01T00:00:00+00:00",
#                 "2024-01-02T00:00:00+00:00"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "Value",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "nameTruncate": {},
#             "nameMoveOverlap": true,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "silent": false,
#             "triggerEvent": false,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": false
#                 }
#             },
#             "animation": true,
#             "animationThreshold": 2000,
#             "animationDuration": 1000,
#             "animationEasing": "cubicOut",
#             "animationDelay": 0,
#             "animationDurationUpdate": 300,
#             "animationEasingUpdate": "cubicOut",
#             "animationDelayUpdate": 0
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "LifetimeDesignVerification",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_772353dc4a364e9ba7f98a6972d1e931.setOption(option_772353dc4a364e9ba7f98a6972d1e931);
#         });
#     </script>

# %% [markdown]
# ## Comparison Example

# %%
frequencies_analysis = LifetimeDesignFrequencies()
frequencies_series = frequencies_analysis.to_results(
    {
        "rows": [
            {
                "turbine": "BBA01",
                "reference": "INFL",
                "FA1": 0.3406,
                "SS1": 0.3407,
                "location_id": 9,
            },
            {
                "turbine": "BBA01",
                "reference": "ACTU",
                "FA1": 0.3330,
                "SS1": 0.3332,
                "location_id": 9,
            },
        ]
    }
)
frequencies_frame = pd.DataFrame([item.to_record_payload(analysis_id=103) for item in frequencies_series])
frequencies_service = ResultsService(repository=StubRepository(frequencies_frame))
frequencies_data = frequencies_service.get_results("LifetimeDesignFrequencies")
frequencies_plot = frequencies_service.plot_results("LifetimeDesignFrequencies")

display(frequencies_data)
frequencies_plot.chart.render_notebook()
# Out:
#       x       y  series_name turbine metric reference
# 0  INFL  0.3406  BBA01 - FA1   BBA01    FA1      INFL
# 1  ACTU  0.3330  BBA01 - FA1   BBA01    FA1      ACTU
# 2  INFL  0.3407  BBA01 - SS1   BBA01    SS1      INFL
# 3  ACTU  0.3332  BBA01 - SS1   BBA01    SS1      ACTU
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v6/echarts.min'
#         }
#     });
# </script>
#
#         <div id="2acfd0588dae46a785b27a51f0b78c0f" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_2acfd0588dae46a785b27a51f0b78c0f = echarts.init(
#                     document.getElementById('2acfd0588dae46a785b27a51f0b78c0f'), 'white', {renderer: 'canvas', locale: 'ZH'});
#                 var option_2acfd0588dae46a785b27a51f0b78c0f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "BBA01 - FA1",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "stackStrategy": "samesign",
#             "data": [
#                 {
#                     "value": 0.3406,
#                     "symbol": "circle",
#                     "symbolSize": 4,
#                     "symbolKeepAspect": false
#                 },
#                 {
#                     "value": 0.333,
#                     "symbol": "circle",
#                     "symbolSize": 4,
#                     "symbolKeepAspect": false
#                 }
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "richInheritPlainLabel": true,
#                 "valueAnimation": false
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": false
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "BBA01 - SS1",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "stackStrategy": "samesign",
#             "data": [
#                 {
#                     "value": 0.3407,
#                     "symbol": "circle",
#                     "symbolSize": 4,
#                     "symbolKeepAspect": false
#                 },
#                 {
#                     "value": 0.3332,
#                     "symbol": "circle",
#                     "symbolSize": 4,
#                     "symbolKeepAspect": false
#                 }
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "richInheritPlainLabel": true,
#                 "valueAnimation": false
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": false
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "BBA01 - FA1",
#                 "BBA01 - SS1"
#             ],
#             "selected": {},
#             "show": true,
#             "top": "5%",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10,
#             "triggerEvent": false
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "displayTransition": true,
#         "textStyle": {
#             "fontSize": 14,
#             "richInheritPlainLabel": true
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "name": "Time / Axis",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "nameTruncate": {},
#             "nameMoveOverlap": true,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "silent": false,
#             "triggerEvent": false,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": false
#                 }
#             },
#             "animation": true,
#             "animationThreshold": 2000,
#             "animationDuration": 1000,
#             "animationEasing": "cubicOut",
#             "animationDelay": 0,
#             "animationDurationUpdate": 300,
#             "animationEasingUpdate": "cubicOut",
#             "animationDelayUpdate": 0,
#             "data": [
#                 "INFL",
#                 "ACTU"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "Value",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "nameTruncate": {},
#             "nameMoveOverlap": true,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "silent": false,
#             "triggerEvent": false,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": false
#                 }
#             },
#             "animation": true,
#             "animationThreshold": 2000,
#             "animationDuration": 1000,
#             "animationEasing": "cubicOut",
#             "animationDelay": 0,
#             "animationDurationUpdate": 300,
#             "animationEasingUpdate": "cubicOut",
#             "animationDelayUpdate": 0
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "LifetimeDesignFrequencies",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_2acfd0588dae46a785b27a51f0b78c0f.setOption(option_2acfd0588dae46a785b27a51f0b78c0f);
#         });
#     </script>
